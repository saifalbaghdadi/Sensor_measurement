# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/0xx.csv')

# %%
data.head(10)
# Out:
#    index   acc_x_n   acc_y_n   acc_z_n   gyr_x_n   gyr_y_n   gyr_z_n  mag_x_n  \
# 0      0 -0.843994  0.182129 -0.487793  0.099602  0.118777  0.026632     1489
# 1      1 -0.840576  0.178223 -0.481934  0.068177  0.166181  0.054861     1489
# 2      2 -0.837646  0.177246 -0.489258  0.045274  0.177367  0.069242     1485
# 3      3 -0.846924  0.171387 -0.479248 -0.005326  0.165116  0.063383     1485
# 4      4 -0.843750  0.185791 -0.486572 -0.004261  0.172573  0.010120     1478
# 5      5 -0.843994  0.178955 -0.488037 -0.007457  0.180030  0.026632     1478
# 6      6 -0.844727  0.174316 -0.485840  0.001065  0.121973  0.057524     1476
# 7      7 -0.843750  0.179688 -0.486328 -0.029827  0.100135  0.086819     1476
# 8      8 -0.845703  0.177490 -0.485596 -0.085221  0.149137  0.042611     1468
# 9      9 -0.848633  0.178467 -0.488281 -0.090015  0.150202  0.067644     1468
#
#    mag_y_n  mag_z_n  ...  mag_y_r  mag_z_r       q1n       q2n       q3n  \
# 0     -197    -6187  ...      743     -946 -0.106322 -0.863679  0.000000
# 1     -197    -6187  ...      743     -946 -0.105675 -0.865430  0.001255
# 2     -204    -6223  ...      692    -1299 -0.105552 -0.867231  0.002505
# 3     -204    -6223  ...      692    -1299 -0.106220 -0.868748  0.003159
# 4     -216    -6219  ...      743     -936 -0.106412 -0.870333  0.002917
# 5     -216    -6219  ...      743     -936 -0.106786 -0.871960  0.002895
# 6     -219    -6206  ...      737     -938 -0.107277 -0.873026  0.003599
# 7     -219    -6206  ...      737     -938 -0.108595 -0.873803  0.004572
# 8     -217    -6205  ...      746     -932 -0.110444 -0.874906  0.004125
# 9     -217    -6205  ...      746     -932 -0.112598 -0.875988  0.004057
#
#         q4n       q1r       q2r       q3r       q4r
# 0  0.492701  0.082074 -0.748462  0.000000  0.658079
# 1  0.489757  0.081589 -0.749364 -0.000402  0.657112
# 2  0.486582  0.080490 -0.750739 -0.001279  0.655676
# 3  0.483719  0.079761 -0.751393 -0.003049  0.655009
# 4  0.480820  0.078088 -0.751785 -0.004714  0.654751
# 5  0.477780  0.075431 -0.752763 -0.006470  0.653924
# 6  0.475714  0.073114 -0.753773 -0.009164  0.652991
# 7  0.473977  0.071563 -0.755209 -0.011031  0.651472
# 8  0.471513  0.070024 -0.756713 -0.012713  0.649861
# 9  0.468989  0.069220 -0.758101 -0.014281  0.648296
#
# [10 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['index', 'acc_x_n', 'acc_y_n', 'acc_z_n', 'gyr_x_n', 'gyr_y_n',
#        'gyr_z_n', 'mag_x_n', 'mag_y_n', 'mag_z_n', 'acc_x_r', 'acc_y_r',
#        'acc_z_r', 'gyr_x_r', 'gyr_y_r', 'gyr_z_r', 'mag_x_r', 'mag_y_r',
#        'mag_z_r', 'q1n', 'q2n', 'q3n', 'q4n', 'q1r', 'q2r', 'q3r', 'q4r'],
#       dtype='object')

# %%
# acceleration in the neck in x,y,z direction
acc_N = data.iloc[:,1:4]
gyr_N = data.iloc[:,4:7]
mag_N = data.iloc[:,7:10]

# quaternion for the neck 
Q_N = data.iloc[:,19:23]

# %%
acceleration =pd.concat([acc_N,gyr_N,mag_N,Q_N],axis=1)
acceleration.head(10)
# Out:
#     acc_x_n   acc_y_n   acc_z_n   gyr_x_n   gyr_y_n   gyr_z_n  mag_x_n  \
# 0 -0.843994  0.182129 -0.487793  0.099602  0.118777  0.026632     1489
# 1 -0.840576  0.178223 -0.481934  0.068177  0.166181  0.054861     1489
# 2 -0.837646  0.177246 -0.489258  0.045274  0.177367  0.069242     1485
# 3 -0.846924  0.171387 -0.479248 -0.005326  0.165116  0.063383     1485
# 4 -0.843750  0.185791 -0.486572 -0.004261  0.172573  0.010120     1478
# 5 -0.843994  0.178955 -0.488037 -0.007457  0.180030  0.026632     1478
# 6 -0.844727  0.174316 -0.485840  0.001065  0.121973  0.057524     1476
# 7 -0.843750  0.179688 -0.486328 -0.029827  0.100135  0.086819     1476
# 8 -0.845703  0.177490 -0.485596 -0.085221  0.149137  0.042611     1468
# 9 -0.848633  0.178467 -0.488281 -0.090015  0.150202  0.067644     1468
#
#    mag_y_n  mag_z_n       q1n       q2n       q3n       q4n
# 0     -197    -6187 -0.106322 -0.863679  0.000000  0.492701
# 1     -197    -6187 -0.105675 -0.865430  0.001255  0.489757
# 2     -204    -6223 -0.105552 -0.867231  0.002505  0.486582
# 3     -204    -6223 -0.106220 -0.868748  0.003159  0.483719
# 4     -216    -6219 -0.106412 -0.870333  0.002917  0.480820
# 5     -216    -6219 -0.106786 -0.871960  0.002895  0.477780
# 6     -219    -6206 -0.107277 -0.873026  0.003599  0.475714
# 7     -219    -6206 -0.108595 -0.873803  0.004572  0.473977
# 8     -217    -6205 -0.110444 -0.874906  0.004125  0.471513
# 9     -217    -6205 -0.112598 -0.875988  0.004057  0.468989

# %%
# Magnetic field measurement in the neck in x,y,z direction
acc_R = data.iloc[:,10:13]
gyr_R = data.iloc[:,13:16]
mag_R = data.iloc[:,16:19]

# quaternion for the belt wearable
Q_R = data.iloc[:,23:27]

# %%
Magnetic =pd.concat([acc_R,gyr_R,mag_R,Q_R],axis=1)
Magnetic.head(10)
# Out:
#     acc_x_r   acc_y_r   acc_z_r   gyr_x_r   gyr_y_r   gyr_z_r  mag_x_r  \
# 0 -0.974854 -0.121582 -0.119141 -0.037817  0.076166 -0.035154    -5410
# 1 -0.979248 -0.117188 -0.114990 -0.035154  0.066046 -0.004261    -5410
# 2 -0.977783 -0.129883 -0.118164 -0.076166  0.097472 -0.000533    -5398
# 3 -0.979980 -0.125244 -0.119629 -0.088417  0.041545 -0.044741    -5398
# 4 -0.979004 -0.121826 -0.117676 -0.119310  0.018642 -0.009055    -5407
# 5 -0.976074 -0.123779 -0.118408 -0.161920  0.059122  0.018642    -5407
# 6 -0.979004 -0.121826 -0.115723 -0.180030  0.062318 -0.028762    -5407
# 7 -0.974609 -0.115723 -0.121338 -0.125701  0.101200 -0.026099    -5407
# 8 -0.978271 -0.118652 -0.120117 -0.119842  0.109190 -0.019175    -5415
# 9 -0.975586 -0.116455 -0.120361 -0.087884  0.105461 -0.039415    -5415
#
#    mag_y_r  mag_z_r       q1r       q2r       q3r       q4r
# 0      743     -946  0.082074 -0.748462  0.000000  0.658079
# 1      743     -946  0.081589 -0.749364 -0.000402  0.657112
# 2      692    -1299  0.080490 -0.750739 -0.001279  0.655676
# 3      692    -1299  0.079761 -0.751393 -0.003049  0.655009
# 4      743     -936  0.078088 -0.751785 -0.004714  0.654751
# 5      743     -936  0.075431 -0.752763 -0.006470  0.653924
# 6      737     -938  0.073114 -0.753773 -0.009164  0.652991
# 7      737     -938  0.071563 -0.755209 -0.011031  0.651472
# 8      746     -932  0.070024 -0.756713 -0.012713  0.649861
# 9      746     -932  0.069220 -0.758101 -0.014281  0.648296
